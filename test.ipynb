# %% [markdown]
# ![test](Documentation/Static/CellMap_overlay.jpg)

# %% [markdown]
# ![test](https://github.com/ChristophKirst/Test/blob/master/Documentation/Static/CellMap_raw.jpg)

# %% [markdown]
# ![_auto_0](attachment:_auto_0)
